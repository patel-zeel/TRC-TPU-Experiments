# %%
import os
import sys

DEFAULT_DEVICE = 'cpu'
os.environ['JAX_PLATFORM_NAME'] = DEFAULT_DEVICE

try:
    from tinygp import GaussianProcess, kernels
except:
    # %pip install -qqq tinygp
    from tinygp import GaussianProcess, kernels

import jax
import jax.numpy as jnp
import numpy as np
import jaxopt
import optax
import matplotlib.pyplot as plt
import pandas as pd

print("The following devices should match with each other. If they don't, restart the kernel")
print(os.environ['JAX_PLATFORM_NAME'])
print(jax.default_backend())
print(jnp.array(1.).device())
# Out:
# The following devices should match with each other. If they don't, restart the kernel
# tpu
# tpu
# TPU_0(process=0,(0,0,0,0))

# %% [markdown]
# ## Functions

# %%
def build_gp(params, x):
    log_kernel, mean, log_noise = params
    kernel = jax.tree_map(jnp.exp, log_kernel)
    noise = jnp.exp(log_noise)
    return GaussianProcess(kernel, x, diag=noise, mean=mean)

@jax.jit
@jax.value_and_grad
def loss_and_grad(params, x, y):
    params, x, y = data
    gp = build_gp(params, x)
    return -gp.log_probability(y)

def optimize_optax(data, epochs, optimizer='optax'):
    params, x, y = data
    if optimizer == 'optax':
        tx = optax.adam(learning_rate=0.1)
        state = tx.init(params)
        for _ in range(epochs):
            val, grads = loss_and_grad(params, x, y)
            updates, state = tx.update(grads, state)
            params = optax.apply_updates(params, updates)
    if optimizer == 'jaxopt':
        opt = jaxopt.ScipyMinimize()

def simulate_data(key, N):
    x = jnp.linspace(-2, 2, N).reshape(-1,1)
    y = jnp.sin(x).flatten() + jax.random.normal(key, shape=(N,))
    
    kernel = jnp.array(1.) * kernels.ExpSquared()
    mean = jnp.array(1.)
    noise = jnp.array(1.)
    return (kernel, mean, noise), x, y

# %% [markdown]
# ### Config

# %%
N_RANGE = range(1000, 11000, 1000)
EPOCHS_RANGE = range(100, 1100, 100)

# %% [markdown]
# ### Training

# %%
res_df = pd.DataFrame(index=N_RANGE, columns=EPOCHS_RANGE)
key = jax.random.PRNGKey(0)

# Warm up
data = simulate_data(key, N=10)
optimize_optax(data, epochs=10)

key_n = 0
for N in N_RANGE:
    for EPOCHS in EPOCHS_RANGE:
        key_n += 1
        key = jax.random.PRNGKey(key_n)
        data = simulate_data(key, N)
        res = %timeit -n1 -r1 -o optimize_optax(data, epochs=EPOCHS)
        res_df.loc[N, EPOCHS] = res.average
        print(f"N: {N}, EPOCHS: {EPOCHS}, TIME: {res.average}")

pd.to_pickle(res_df, f"results/simple_{DEFAULT_DEVICE}_timings.pkl")
# Out:
# /home/zeelp/miniconda/lib/python3.9/site-packages/jax/_src/tree_util.py:185: FutureWarning: jax.tree_util.tree_multimap() is deprecated. Please use jax.tree_util.tree_map() instead as a drop-in replacement.
#   warnings.warn('jax.tree_util.tree_multimap() is deprecated. Please use jax.tree_util.tree_map() '
# 4.89 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 1000, EPOCHS: 100, TIME: 4.89262199899531
# 3.92 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 1000, EPOCHS: 200, TIME: 3.915820588998031
# 4.94 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 1000, EPOCHS: 300, TIME: 4.936778488001437
# 6.01 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 1000, EPOCHS: 400, TIME: 6.014353514001414
# 6.97 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 1000, EPOCHS: 500, TIME: 6.9709677179998835
# 8 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 1000, EPOCHS: 600, TIME: 8.002400973004114
# 9.29 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 1000, EPOCHS: 700, TIME: 9.288252903999819
# 10.4 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 1000, EPOCHS: 800, TIME: 10.418700685004296
# 11.1 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 1000, EPOCHS: 900, TIME: 11.05091419499513
# 12.9 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 1000, EPOCHS: 1000, TIME: 12.856943800004956
# 4.75 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 2000, EPOCHS: 100, TIME: 4.754263873001037
# 2.08 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 2000, EPOCHS: 200, TIME: 2.080030174998683
# 3.15 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 2000, EPOCHS: 300, TIME: 3.1545820440005627
# 4.23 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 2000, EPOCHS: 400, TIME: 4.227691081003286
# 5.38 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 2000, EPOCHS: 500, TIME: 5.376684353999735
# 6.31 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 2000, EPOCHS: 600, TIME: 6.308121963003941
# 8.59 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 2000, EPOCHS: 700, TIME: 8.59185981000337
# 8.99 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 2000, EPOCHS: 800, TIME: 8.985536700994999
# 9.23 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 2000, EPOCHS: 900, TIME: 9.230905750999227
# 10.3 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 2000, EPOCHS: 1000, TIME: 10.293749199001468
# 6.68 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 3000, EPOCHS: 100, TIME: 6.679210622998653
# 2.82 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 3000, EPOCHS: 200, TIME: 2.8153508359973785
# 4.24 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 3000, EPOCHS: 300, TIME: 4.240967259000172
# 5.61 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 3000, EPOCHS: 400, TIME: 5.608992127999954
# 7.03 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 3000, EPOCHS: 500, TIME: 7.033366917996318
# 8.52 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 3000, EPOCHS: 600, TIME: 8.516287489997922
# 9.85 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 3000, EPOCHS: 700, TIME: 9.854286021000007
# 11.2 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 3000, EPOCHS: 800, TIME: 11.201626496003882
# 12.7 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 3000, EPOCHS: 900, TIME: 12.652507111000887
# 14.5 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 3000, EPOCHS: 1000, TIME: 14.502929488997324
# 10.4 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 4000, EPOCHS: 100, TIME: 10.443484613999317
# 4 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 4000, EPOCHS: 200, TIME: 4.000770979000663
# 6.01 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 4000, EPOCHS: 300, TIME: 6.0076059460043325
# 7.95 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 4000, EPOCHS: 400, TIME: 7.95180151599925
# 9.98 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 4000, EPOCHS: 500, TIME: 9.976052486999833
# 12 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 4000, EPOCHS: 600, TIME: 12.029313546001504
# 13.6 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 4000, EPOCHS: 700, TIME: 13.55850086099963
# 15.7 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 4000, EPOCHS: 800, TIME: 15.698372711005504
# 17.4 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 4000, EPOCHS: 900, TIME: 17.431703191999986
# 20 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 4000, EPOCHS: 1000, TIME: 19.991722995997407
# 15.6 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 5000, EPOCHS: 100, TIME: 15.583039311000903
# 5.59 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 5000, EPOCHS: 200, TIME: 5.593661320002866
# 8.35 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 5000, EPOCHS: 300, TIME: 8.353602022994892
# 11.2 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 5000, EPOCHS: 400, TIME: 11.163916024001082
# 13.8 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 5000, EPOCHS: 500, TIME: 13.848358436996932
# 16.6 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 5000, EPOCHS: 600, TIME: 16.643992744997377
# 19.6 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 5000, EPOCHS: 700, TIME: 19.61380931399617
# 22.4 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 5000, EPOCHS: 800, TIME: 22.397086775003118
# 25 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 5000, EPOCHS: 900, TIME: 24.985410076995322
# 27.7 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 5000, EPOCHS: 1000, TIME: 27.722387062000053
# 18.9 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 6000, EPOCHS: 100, TIME: 18.87914243099658
# 7.66 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 6000, EPOCHS: 200, TIME: 7.6556637859976036
# 11.6 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 6000, EPOCHS: 300, TIME: 11.584988259004604
# 15.4 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 6000, EPOCHS: 400, TIME: 15.414815474003262
# 19.2 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 6000, EPOCHS: 500, TIME: 19.19476391599892
# 22.9 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 6000, EPOCHS: 600, TIME: 22.940163038998435
# 26.5 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 6000, EPOCHS: 700, TIME: 26.526211880001938
# 30.4 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 6000, EPOCHS: 800, TIME: 30.375070268994023
# 34.4 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 6000, EPOCHS: 900, TIME: 34.393369514997175
# 38 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 6000, EPOCHS: 1000, TIME: 37.98337557200284
# 26.2 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 7000, EPOCHS: 100, TIME: 26.22318658500444
# 10.5 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 7000, EPOCHS: 200, TIME: 10.485461870994186
# 15.7 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 7000, EPOCHS: 300, TIME: 15.696201972998097
# 21 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 7000, EPOCHS: 400, TIME: 21.024122663002345
# 26.3 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 7000, EPOCHS: 500, TIME: 26.34571302800032
# 31.5 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 7000, EPOCHS: 600, TIME: 31.462174346997926
# 36.6 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 7000, EPOCHS: 700, TIME: 36.62351744300395
# 41.8 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 7000, EPOCHS: 800, TIME: 41.78671306199976
# 47.1 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 7000, EPOCHS: 900, TIME: 47.14872199200181
# 52.5 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 7000, EPOCHS: 1000, TIME: 52.52688651999779
# 30.8 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 8000, EPOCHS: 100, TIME: 30.797870778005745
# 14 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 8000, EPOCHS: 200, TIME: 13.984299512994767
# 21 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 8000, EPOCHS: 300, TIME: 20.984809084002336
# 28 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 8000, EPOCHS: 400, TIME: 28.007284472994797
# 35 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 8000, EPOCHS: 500, TIME: 34.967230398004176
# 41.9 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 8000, EPOCHS: 600, TIME: 41.947761883995554
# 49.1 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 8000, EPOCHS: 700, TIME: 49.059068488000776
# 56 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 8000, EPOCHS: 800, TIME: 55.96019904300192
# 1min 3s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 8000, EPOCHS: 900, TIME: 63.00906633200066
# 1min 9s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 8000, EPOCHS: 1000, TIME: 69.97867257699545
# 41.8 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 9000, EPOCHS: 100, TIME: 41.76834793699527
# 19.8 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 9000, EPOCHS: 200, TIME: 19.84544792000088
# 29.8 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 9000, EPOCHS: 300, TIME: 29.803312709998863
# 39.8 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 9000, EPOCHS: 400, TIME: 39.77884626300511
# 49.7 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 9000, EPOCHS: 500, TIME: 49.70551778299705
# 59.3 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 9000, EPOCHS: 600, TIME: 59.32340801400278
# 1min 9s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 9000, EPOCHS: 700, TIME: 69.3176053520001
# 1min 19s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 9000, EPOCHS: 800, TIME: 79.49450518700178
# 1min 29s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# N: 9000, EPOCHS: 900, TIME: 89.45284346699918

# %% [markdown]
# ### Plot the timings

# %%
SCALE = 10

def get_results(device):
    df = pd.read_pickle(f"results/simple_{device}_timings.pkl")
    n_grid, epoch_grid = map(np.ravel, np.meshgrid(df.index, df.columns))
    time_grid = df.values.flatten().astype(np.float32)
    return n_grid, epoch_grid, time_grid

# cpu_n, cpu_epochs, cpu_time = get_results('cpu')
tpu_n, tpu_epochs, tpu_time = get_results('tpu')

plt.figure(figsize=(10,6))
plt.rc('font', size=20)
# plt.scatter(cpu_n, cpu_epochs, s=SCALE*cpu_time, label="cpu", alpha=0.2)
plt.scatter(tpu_n, tpu_epochs, s=SCALE*tpu_time, label="tpu", alpha=0.2)
plt.xlabel('Number of datapoints')
plt.ylabel('Number of epochs');
plt.legend(bbox_to_anchor=(1,1));
